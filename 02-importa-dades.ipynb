# %%
# UOC - Visualització de dades - PRA2 
# Preparació de dades: importa TXT i exporta un CSV
# @author: José V. Grimalt
# 2022-01-15

# import packages
import re
import collections
import pandas as pd
from datetime import datetime, timedelta

# noms dels fitxers
file_municipis = "municipios_pob_2022-01-01.csv"  # dades de població dels municipis
file_fieldnames = "dades-camps.csv"               # dades dels camps del fitxer de matriculacions

# %%
# definició de funció per llevar accents

def remove_accents(word):
    "Removes common accent characters, upper form. Uses: regex."
    new_word = word.upper()
    new_word = re.sub(r'[àáÀÁ]', 'A', new_word)
    new_word = re.sub(r'[èéÈÉ]', 'E', new_word)
    new_word = re.sub(r'[ìíïÌÍÏ]', 'I', new_word)
    new_word = re.sub(r'[òóÒÓ]', 'O', new_word)
    new_word = re.sub(r'[ùúüÙÚÜ]', 'U', new_word)
    new_word = re.sub(r'[\-\']', ' ', new_word)
    return new_word

def last_day_of_month(input_date):
    "Return last day of month from given date"
    next_month = input_date.replace(day=28) + timedelta(days=4)
    return next_month - timedelta(days=next_month.day)

# càrrega dades sobre els camps del fitxer de matriculacions
fields = pd.read_csv(file_fieldnames, index_col=0).reset_index()

widths = list(fields.Longitud)

# càrrega de dades de municipis
municipis = pd.read_csv(file_municipis, index_col=0).reset_index()

# Dades dels 151 municipis amb major població
dict_municipis = collections.defaultdict(lambda: 'Otros')
dict_municipis.update({
    remove_accents(x[0]): x[1] 
        for x in municipis.loc[0:151, ["Municipio", "Nombre"]].values
})

# Selecció de camps
fields_list = [
    "MARCA_ITV", "MODELO_ITV", "COD_TIPO", "COD_PROPULSION_ITV", 
    "LOCALIDAD_VEHICULO", "COD_PROVINCIA_VEH", "MUNICIPIO", 
    "CLAVE_TRAMITE", "IND_NUEVO_USADO", 
    "PERSONA_FISICA_JURIDICA", "RENTING", 
    "CO2_ITV", "CATEGORÍA_VEHÍCULO_ELÉCTRICO", "AUTONOMÍA_VEHÍCULO_ELÉCTRICO", 
    "FEC_PROCESO", "FEC_MATRICULA", "FEC_TRAMITACION"
]

# paràmetres i fitxers
file_municipis = "municipios_pob_2022-01-01.csv"  # dades de població dels municipis
file_fieldnames = "dades-camps.csv"               # informació dels camps del fitxer 

file_input_txt = [                                # fitxer de matriculacions
    f"txt/export_mensual_mat_{year}{month:02d}.zip" 
        for year in range(2018, 2023) for month in range(1, 13) 
]
file_output_csv = [                               # fitxer de dades agrupades
    f"csv/matriculacion_{year}{month:02d}.csv" 
        for year in range(2018, 2023) for month in range(1, 13)
]

# TTIPO_VEHICULO
dict_tipo = {
    "0": "CAMION",
    "1": "CAMION ARTICULADO",
    "2": "FURG./TODOTERR.",
    "3": "AUTOBUS",
    "4": "TURISMO",
    "5": "MOTOCICLETA/QUAD",
    "6": "COCHE DIVERS.FUNC.",
    "7": "MAQUINARIA",
    "8": "TRACTOR",
    "9": "CICLOMOTOR",
    "E": "EXTRANJERO",
    "R": "REMOLQ./MAQ. AGRÍCOLA",
    "S": "SEMIREMOLQUE",
}

# COD_PROPULSION_ITV
dict_propulsion = {
    "0": "Gasolina",
    "1": "Diesel",
    "2": "Eléctrico",
    "3": "Otros",
    "4": "Butano",
    "5": "Solar",
    "6": "GLP", # "Gas Licuado de Petróleo",
    "7": "GNC", # Gas Natural Comprimido",
    "8": "GNL", # "Gas Natural Licuado",
    "9": "Hidrógeno",
    "A": "Biometano",
    "B": "Etanol",
    "C": "Biodiesel",
    "99": "[N/A]",
}

# camp COD_PROVINCIA_VEH
dict_provincia = {
    "A"  : "Alacant",
    "AB" : "Albacete",
    "AL" : "Almería",
    "AV" : "Ávila",
    "B"  : "Barcelona",
    "BA" : "Badajoz",
    "BI" : "Bizkaia",
    "BU" : "Burgos",
    "C"  : "Coruña (A)",
    "CA" : "Cádiz",
    "CC" : "Cáceres",
    "CE" : "Ceuta",
    "CO" : "Córdoba",
    "CR" : "Ciudad Real",
    "CS" : "Castelló",
    "CU" : "Cuenca",
    "DS" : "Desconocido",
    "EX" : "Extranjero",
    "GC" : "Palmas (Las)",
    "GI" : "Girona",
    "GR" : "Granada",
    "GU" : "Guadalajara",
    "H"  : "Huelva",
    "HU" : "Huesca",
    "J"  : "Jaén",
    "L"  : "Lleida",
    "LE" : "León",
    "LO" : "Rioja (La)",
    "LU" : "Lugo",
    "M"  : "Madrid",
    "MA" : "Málaga",
    "ML" : "Melilla",
    "MU" : "Murcia",
    "NA" : "Navarra",
    "O"  : "Asturias",
    "OU" : "Ourense",
    "P"  : "Palencia",
    "IB" : "Balears (Illes)",
    "PO" : "Pontevedra",
    "S"  : "Cantabria",
    "SA" : "Salamanca",
    "SE" : "Sevilla",
    "SG" : "Segovia",
    "SO" : "Soria",
    "SS" : "Gipuzkoa",
    "T"  : "Tarragona",
    "TE" : "Teruel",
    "TF" : "Santa Cruz de Tenerife",
    "TO" : "Toledo",
    "V"  : "València",
    "VA" : "Valladolid",
    "VI" : "Araba",
    "Z"  : "Zaragoza",
    "ZA" : "Zamora",
}

# CLAVE_TRAMITE
dict_tramite = {
    "1": "Matriculación ordinaria", 
    "2": "Transferencia", 
    "3": "Baja definitiva", 
    "4": "Baja definitiva Plan Renove", 
    "5": "Rematriculación", 
    "6": "Baja temporal", 
    "7": "Baja definitiva Exportación/Tránsito comunitario", 
    "8": "Matriculación vehículo especial", 
    "9": "Matriculación temporal", 
    "A": "Prorroga matricula temporal", 
    "B": "Matrícula temporal a definitiva", 
}

# IND_NUEVO_USADO
dict_nuevousado = {"N": "Nuevo", "U": "Usado"}

# PERSONA_FISICA_JURIDICA
dict_persona = {"D": "Particular", "X": "Empresa"}

# RENTING
dict_renting = {"N": "NO", "S": "SI"}

# PROPULSIÓN / ELÉCTRICO --> MOTOR / COMBUSTIBLE / TECNOLOGÍA
# dict_motor_combustible = dict()
dict_motor_combustible = collections.defaultdict(lambda: ("Combustión", "Combustión G/D","Combustión"))
dict_motor_combustible.update({
    ("[N/A]", "[N/A]"):    ("Combustión", "Combustión G/D", "Combustión"),
    ("Diesel", "HEV"):     ("Combustión", "Diesel",    "HEV"),
    ("Diesel", "PHEV"):    ("Eléctrico",  "Diesel",    "PHEV"),
    ("Diesel", "REEV"):    ("Eléctrico",  "Diesel",    "REEV"),
    ("Diesel", "[N/D]"):   ("Combustión", "Diesel",    "Combustión"),
    ("Gasolina", "HEV"):   ("Combustión", "Gasolina",  "HEV"),
    ("Gasolina", "PHEV"):  ("Eléctrico",  "Gasolina",  "PHEV"),
    ("Gasolina", "REEV"):  ("Eléctrico",  "Gasolina",  "REEV"),
    ("Gasolina", "[N/D]"): ("Combustión", "Gasolina",  "Combustión"),
    ("GLP", "HEV"):        ("Combustión", "GLP",       "HEV"),
    ("GLP", "PHEV"):       ("Eléctrico",  "GLP",       "PHEV"),
    ("GLP", "REEV"):       ("Eléctrico",  "GLP",       "REEV"),
    ("GLP", "[N/D]"):      ("Combustión", "GLP",       "GLP"),
    ("GNC", "HEV"):        ("Combustión", "GNC",       "HEV"),
    ("GNC", "PHEV"):       ("Eléctrico",  "GNC",       "PHEV"),
    ("GNC", "REEV"):       ("Eléctrico",  "GNC",       "REEV"),
    ("GNC", "[N/D]"):      ("Combustión", "GNC",       "GNC"),
    ("GNL", "HEV"):        ("Combustión", "GNL",       "HEV"),
    ("GNL", "PHEV"):       ("Eléctrico",  "GNL",       "PHEV"),
    ("GNL", "REEV"):       ("Eléctrico",  "GNL",       "REEV"),
    ("GNL", "[N/D]"):      ("Combustión", "GNL",       "GNL"),
    ("Eléctrico", "BEV"):  ("Eléctrico",  "Eléctrico", "BEV"),
    ("Eléctrico", "HEV"):  ("Combustión", "Gasolina",  "HEV"),
    ("Eléctrico", "PHEV"): ("Eléctrico",  "Gasolina",  "PHEV"),
    ("Eléctrico", "REEV"): ("Eléctrico",  "Gasolina",  "REEV"),
    ("Eléctrico", "[N/D]"):("Eléctrico",  "Eléctrico", "BEV"),
    ("Hidrógeno", "HEV"):  ("Eléctrico",  "Hidrógeno", "HEV"),
    ("Hidrógeno", "PHEV"): ("Eléctrico",  "Hidrógeno", "PHEV"),
    ("Hidrógeno", "REEV"): ("Eléctrico",  "Hidrógeno", "REEV"),
    ("Hidrógeno", "[N/D]"):("Eléctrico",  "Hidrógeno", "Hidrógeno"),
    ("Otros", "BEV"):      ("Eléctrico",  "Otros",     "BEV"),
    ("Otros", "HEV"):      ("Combustión", "Otros",     "HEV"),
    ("Otros", "PHEV"):     ("Eléctrico",  "Otros",     "PHEV"),
    ("Otros", "REEV"):     ("Eléctrico",  "Otros",     "REEV"),
    ("Otros", "[N/D]"):    ("Combustión", "Otros",     "Combustión"),
})

df_total = pd.DataFrame()
rows = collections.defaultdict(lambda: 0)

# %%
# Bucle principal per als fitxers mensuals

# for file_txt, file_csv in zip(file_input_txt, file_output_csv):
first = 0
last = len(file_input_txt) - 1
files = zip(file_input_txt[first:last+1], file_output_csv[first:last+1])
for file_txt, file_csv in files:
    print(f"- Reading file: '{file_txt}'")

    raw_data = pd.read_fwf(
        file_txt, compression='zip', skiprows=1, 
        names=fields.Campo, widths=widths, encoding='latin-1', 
    )
    print(f"  - rows in file: {len(raw_data)}")
    rows["TOTAL"] += len(raw_data)

    df = raw_data[fields_list].copy(deep=True)

    # transformar camp de data: FEC_PROCESO 
    date_fields = ["FEC_PROCESO", "FEC_MATRICULA", ]
    for field in date_fields:
        df[field] = pd.to_datetime(df.loc[:, field], format="%d%m%Y", errors='coerce')

    # comprovar valors nuls en camps de data
    # for field in date_fields:
    #     print(field, df.loc[:, [field]].isna().sum())

    # camp FEC_PROCESO -> FECHA, PERIODO
    # df["PERIODO"] = df["FEC_PROCESO"].dt.strftime('%Y-%m')
    # df["FECHA"] = df["FEC_PROCESO"].map(last_day_of_month)
    last_day = df["FEC_PROCESO"].max()
    df["PERIODO"] = last_day.strftime('%Y-%m')
    df["FECHA"] = last_day_of_month(last_day)

    # print( df.groupby(["FEC_PROCESO", "PERIODO", "FECHA"])[["FECHA"]].count(), )
    # print(df[df["PERIODO"]=="2022-01"][["FEC_PROCESO", "FEC_MATRICULA", "CLAVE_TRAMITE", ]])

    # camp COD_TIPO -> TIPO_VEHICULO
    field_old = "COD_TIPO"
    field_new = "TIPO_VEHÍCULO"
    df[field_new] = df[field_old].str[0]
    df = df[(df[field_new] < '5')]
    # fem la substitució:
    df = df.replace({field_new: dict_tipo})
    # print(df.groupby([field_new,])[field_new].count())
    rows["TIPO"] += len(df)
    
    # camp COD_PROPULSION_ITV
    field_old = "COD_PROPULSION_ITV"
    field_new = "PROPULSIÓN"
    # print(df.groupby(field_old)[field_old].count())
    
    # tractament de nulls
    if (df[field_old].dtypes == int) or (df[field_old].dtypes == float):
        df[field_new] = df[field_old].fillna(99).astype(int).astype(str)
    else:
        df[field_new] = df[field_old].fillna("99")
    # transformació
    df[field_new] = df[field_new].map(dict_propulsion)
    
    ######################################################################################
    # print(df.groupby(field_new)[field_new].count())

    # camp COD_PROVINCIA_VEH
    field_old = "COD_PROVINCIA_VEH"
    field_new = "PROVINCIA"
    # print("NA:", df[field_old].isna().sum())
    # print(df.groupby([field_old,])[field_old].count())
    df[field_new] = df[field_old].map(dict_provincia)
    # print(df[field_new])
    # print("PROVINCIA N/A:", df[field_new].isna().sum())
    # print(df.groupby(field_new)[field_new].count())

    # Nou camp: POBLACIÓN
    field_old = "MUNICIPIO"
    field_new = "POBLACIÓN"
    df[field_new] = df[field_old].map(dict_municipis)
    # print(df.groupby(field_new)[field_new].count())

    # camp CLAVE_TRAMITE
    # 1 Matriculación ordinaria y de ciclomotores
    # 5 Rematriculación
    # 9 Matriculación temporal
    # B Paso de matrícula temporal a definitiva
    field_old = "CLAVE_TRAMITE"
    field_new = "TRAMITE"
    # print(df.groupby([field_old,])[field_old].count())
    # Filtre: es quedem sols amb "Matriculación ordinaria" i "Paso de matrícula temporal a definitiva"
    df = df[(df[field_old]=='1') | (df[field_old]=='B')]
    # Valor per al nou camp:
    df[field_new] = df[field_old].map(dict_tramite)
    # print(df[field_new])
    # print(df.groupby(field_new)[field_new].count())
    rows["TRAMITE"] += len(df)

    # camp IND_NUEVO_USADO
    # N nuevo
    # U usado
    field_old = "IND_NUEVO_USADO"
    field_new = "NUEVO_USADO"
    # print(df.groupby([field_old,])[field_old].count())
    df[field_new] = df[field_old].map(dict_nuevousado)
    # print(df.groupby(field_new)[field_new].count())

    # camp PERSONA_FISICA_JURIDICA
    # D persona física
    # X persona jurídica
    field_old = "PERSONA_FISICA_JURIDICA"
    field_new = "PROPIETARIO"
    # print(df.groupby([field_old,])[field_old].count())
    df[field_new] = df[field_old].map(dict_persona)
    # print(df.groupby(field_new)[field_new].count())

    # nou camp EMISIONES : sí (tenim registre CO2), no (no tenim)
    # després podem posar a 0 el valors CO2 per als que no tenim emissions
    df["REG_EMISIONES"] = df["CO2_ITV"].isna()
    df["REG_EMISIONES"] = df["REG_EMISIONES"].map({True:"NO", False:"SÍ"})
    # print(df.groupby("REG_EMISIONES")["REG_EMISIONES"].count())
    # print(df.groupby("REG_EMISIONES")["CO2_ITV"].sum())
    # Convertim valors nulls a 0
    df["CO2_ITV"] = df["CO2_ITV"].fillna(0)

    # camp RENTING (N: no, S: sí)
    field = "RENTING"
    df[field] = df[field].map(dict_renting)
    # print("\nRenting:\n", df.groupby(field)[field].count())

    # camp CATEGORÍA_VEHÍCULO_ELÉCTRICO
    field_old = "CATEGORÍA_VEHÍCULO_ELÉCTRICO"
    field_new = "TIPO_ELECTRICO"
    df = df.rename(columns={field_old: field_new})
    # df.groupby([field_new,])[field_new].count()

    # camp AUTONOMÍA_VEHÍCULO_ELÉCTRICO  -> per a convertir a km. -> x / 100
    field = "AUTONOMÍA_VEHÍCULO_ELÉCTRICO"
    # df[field] = df[field].astype(int) / 100
    df[field] = df[field].fillna("000000")
    df[df[field].str[-2:] != "00"][field]
    if (df[field].dtypes == object):
        df[field] = df[field].str[:-2]
        df[field] = pd.to_numeric(df[field], errors='coerce').fillna(0)
    else: 
        df[field] = df[field].fillna(0) / 100
        df[field] = df[field] / 100
    # df.loc[:, "AUTONOMÍA_VEHÍCULO_ELÉCTRICO"].describe()

    # Elimminem outlayers (autonomía > 2000km)
    # print(df[df["AUTONOMÍA_VEHÍCULO_ELÉCTRICO"] > 2000].loc[:, ["MARCA_ITV", "MODELO_ITV", "AUTONOMÍA_VEHÍCULO_ELÉCTRICO"]])
    df = df[df["AUTONOMÍA_VEHÍCULO_ELÉCTRICO"] < 2000]

    # reanomenem les columnes
    df = df.rename(columns = {
        "TIPO_VEHÍCULO": "VEHÍCULO",
        "MARCA_ITV": "MARCA",
        "MODELO_ITV": "MODELO",
        "CO2_ITV": "CO2",
        "TIPO_ELECTRICO": "ELÉCTRICO",
        "AUTONOMÍA_VEHÍCULO_ELÉCTRICO": "AUTONOMÍA",
    })

    print(f"  - Files: {len(df)}")

    # Escollim els camps finals
    camps = [
        'FECHA', 'PERIODO', 'PROVINCIA', 'POBLACIÓN', 
        'VEHÍCULO', 'MARCA', 'MODELO', 'PROPULSIÓN', 
        'REG_EMISIONES', 'CO2', 'ELÉCTRICO', 'AUTONOMÍA', 
        'PROPIETARIO', 'NUEVO_USADO', 'RENTING', 
    ]
    df = df.loc[:, camps]

    # Comprovació de valors nuls
    print("  - Valors nuls:")
    v_nuls = df.isna().sum() 
    print(v_nuls[v_nuls>0])
    rows["N/A"] += len(v_nuls)

    # tractament de valors nuls:
    for field in ["MARCA", "MODELO", "ELÉCTRICO", "PROVINCIA", "RENTING", ]:
        df[field] = df[field].fillna("[N/D]")
    
    # Camps transformació: PROPULSIÓN / ELÉCTRICO --> MOTOR / COMBUSTIBLE / TECNOLOGÍA
    df["input"] = list(zip(df["PROPULSIÓN"], df["ELÉCTRICO"]))
    print(
        df.groupby(["PROPULSIÓN", "ELÉCTRICO"])["PROPULSIÓN"].count()
    )
    df["output"] = df["input"].map(dict_motor_combustible)
    df["MOTOR"] = df["output"].str[0]
    df["COMBUSTIBLE"] = df["output"].str[1]
    df["TECNOLOGÍA"] = df["output"].str[2]
    df = df.drop(columns=["input", "output"])
    print(
        df.groupby(["MOTOR", "COMBUSTIBLE", "TECNOLOGÍA"])["MOTOR"].count()
    )

    # df = df.drop(columns=["CANTIDAD"])
    df["CANTIDAD"] = 1

    # agrupar dades
    fields_group = [
        'FECHA', 'PERIODO', 'PROVINCIA', 'POBLACIÓN', 
        'VEHÍCULO', 'MOTOR', 'COMBUSTIBLE', 'TECNOLOGÍA',
        'REG_EMISIONES',  
    ]
    dades = df.groupby(fields_group)[["CO2", "CANTIDAD"]].sum().reset_index()
    total =  dades["CANTIDAD"].sum()
    dades["%"] = dades["CANTIDAD"] / total * 100
    print(f"  - Total rows: {len(dades)}")
    print(f"  - Total vehicles: {total}")
    dades.to_csv(file_csv, sep=",", index=False)
    rows["GROUP"] += len(dades)

for (k, v) in rows.items():
    print(f"{k}: {v}")
# Out:
# - Reading file: 'txt/export_mensual_mat_201801.zip'
#   - rows in file: 148478
#   - Files: 126259
#   - Valors nuls:
# PROVINCIA      1519
# ELÉCTRICO    119362
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Butano      HEV              1
# Diesel      HEV            104
#             PHEV             1
#             [N/D]        63902
# Eléctrico   BEV            522
#             HEV              6
#             PHEV           309
#             REEV            21
#             [N/D]           35
# GLP         HEV              3
#             [N/D]          716
# GNC         [N/D]          386
# GNL         [N/D]            8
# Gasolina    HEV           5864
#             PHEV            64
#             [N/D]        54311
# Otros       HEV              2
# [N/A]       [N/D]            4
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión        5
#             Diesel          Combustión    63902
#                             HEV             104
#             GLP             GLP             716
#                             HEV               3
#             GNC             GNC             386
#             GNL             GNL               8
#             Gasolina        Combustión    54311
#                             HEV            5870
#             Otros           HEV               2
# Eléctrico   Diesel          PHEV              1
#             Eléctrico       BEV             557
#             Gasolina        PHEV            373
#                             REEV             21
# Name: MOTOR, dtype: int64
#   - Total rows: 2264
#   - Total vehicles: 126259
# - Reading file: 'txt/export_mensual_mat_201802.zip'
#   - rows in file: 156803
#   - Files: 136314
#   - Valors nuls:
# PROVINCIA      1436
# ELÉCTRICO    130107
# RENTING           2
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Diesel      HEV             85
#             PHEV             1
#             [N/D]        64672
# Eléctrico   BEV            486
#             HEV              6
#             PHEV           238
#             REEV            26
#             [N/D]            6
# GLP         HEV              2
#             [N/D]          807
# GNC         [N/D]          421
# GNL         [N/D]            5
# Gasolina    HEV           5252
#             PHEV           106
#             [N/D]        64160
# Hidrógeno   PHEV             5
# [N/A]       [N/D]           36
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión       36
#             Diesel          Combustión    64672
#                             HEV              85
#             GLP             GLP             807
#                             HEV               2
#             GNC             GNC             421
#             GNL             GNL               5
#             Gasolina        Combustión    64160
#                             HEV            5258
# Eléctrico   Diesel          PHEV              1
#             Eléctrico       BEV             492
#             Gasolina        PHEV            344
#                             REEV             26
#             Hidrógeno       PHEV              5
# Name: MOTOR, dtype: int64
#   - Total rows: 2237
#   - Total vehicles: 136314
# - Reading file: 'txt/export_mensual_mat_201803.zip'
#   - rows in file: 179865
#   - Files: 155568
#   - Valors nuls:
# PROVINCIA      1592
# MODELO            1
# ELÉCTRICO    149197
# RENTING           1
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Biodiesel   HEV              1
# Diesel      HEV             86
#             PHEV             2
#             [N/D]        69656
# Eléctrico   BEV            613
#             HEV              3
#             PHEV           233
#             REEV            25
#             [N/D]            2
# GLP         [N/D]          941
# GNC         [N/D]          506
# GNL         [N/D]            1
# Gasolina    HEV           5327
#             PHEV            75
#             [N/D]        77896
# Hidrógeno   PHEV             6
# [N/A]       [N/D]          195
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión      196
#             Diesel          Combustión    69656
#                             HEV              86
#             GLP             GLP             941
#             GNC             GNC             506
#             GNL             GNL               1
#             Gasolina        Combustión    77896
#                             HEV            5330
# Eléctrico   Diesel          PHEV              2
#             Eléctrico       BEV             615
#             Gasolina        PHEV            308
#                             REEV             25
#             Hidrógeno       PHEV              6
# Name: MOTOR, dtype: int64
#   - Total rows: 2352
#   - Total vehicles: 155568
# - Reading file: 'txt/export_mensual_mat_201804.zip'
#   - rows in file: 169745
#   - Files: 143624
#   - Valors nuls:
# PROVINCIA      1567
# ELÉCTRICO    136653
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Diesel      HEV             63
#             PHEV             2
#             [N/D]        65825
# Eléctrico   BEV            593
#             HEV             22
#             PHEV           205
#             REEV            26
#             [N/D]           13
# Etanol      [N/D]            1
# GLP         HEV              2
#             [N/D]         1566
# GNC         [N/D]          485
# GNL         [N/D]           12
# Gasolina    HEV           5991
#             PHEV            67
#             [N/D]        68549
# [N/A]       [N/D]          202
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión      203
#             Diesel          Combustión    65825
#                             HEV              63
#             GLP             GLP            1566
#                             HEV               2
#             GNC             GNC             485
#             GNL             GNL              12
#             Gasolina        Combustión    68549
#                             HEV            6013
# Eléctrico   Diesel          PHEV              2
#             Eléctrico       BEV             606
#             Gasolina        PHEV            272
#                             REEV             26
# Name: MOTOR, dtype: int64
#   - Total rows: 2396
#   - Total vehicles: 143624
# - Reading file: 'txt/export_mensual_mat_201805.zip'
#   - rows in file: 195826
#   - Files: 164909
#   - Valors nuls:
# PROVINCIA      1768
# ELÉCTRICO    157027
# RENTING           2
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Biometano   [N/D]            1
# Butano      [N/D]            1
# Diesel      HEV            145
#             PHEV             2
#             [N/D]        73561
# Eléctrico   BEV            404
#             HEV             15
#             PHEV           258
#             REEV            28
#             [N/D]            5
# GLP         HEV              1
#             [N/D]         1711
# GNC         [N/D]          559
# GNL         [N/D]            8
# Gasolina    HEV           6817
#             PHEV           211
#             [N/D]        80940
# Otros       HEV              1
#             [N/D]            1
# [N/A]       [N/D]          240
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión      242
#             Diesel          Combustión    73561
#                             HEV             145
#             GLP             GLP            1711
#                             HEV               1
#             GNC             GNC             559
#             GNL             GNL               8
#             Gasolina        Combustión    80940
#                             HEV            6832
#             Otros           Combustión        1
#                             HEV               1
# Eléctrico   Diesel          PHEV              2
#             Eléctrico       BEV             409
#             Gasolina        PHEV            469
#                             REEV             28
# Name: MOTOR, dtype: int64
#   - Total rows: 2402
#   - Total vehicles: 164909
# - Reading file: 'txt/export_mensual_mat_201806.zip'
#   - rows in file: 203687
#   - Files: 172180
#   - Valors nuls:
# PROVINCIA      1774
# ELÉCTRICO    162652
# RENTING           1
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Butano      [N/D]            2
# Diesel      HEV            122
#             PHEV             3
#             [N/D]        76837
# Eléctrico   BEV            480
#             HEV             20
#             PHEV           452
#             REEV            48
#             [N/D]            6
# GLP         PHEV             2
#             [N/D]         1971
# GNC         [N/D]          752
# GNL         [N/D]            2
# Gasolina    HEV           7933
#             PHEV           467
#             [N/D]        82860
# Otros       HEV              1
# Solar       [N/D]            1
# [N/A]       [N/D]          221
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión      224
#             Diesel          Combustión    76837
#                             HEV             122
#             GLP             GLP            1971
#             GNC             GNC             752
#             GNL             GNL               2
#             Gasolina        Combustión    82860
#                             HEV            7953
#             Otros           HEV               1
# Eléctrico   Diesel          PHEV              3
#             Eléctrico       BEV             486
#             GLP             PHEV              2
#             Gasolina        PHEV            919
#                             REEV             48
# Name: MOTOR, dtype: int64
#   - Total rows: 2469
#   - Total vehicles: 172180
# - Reading file: 'txt/export_mensual_mat_201807.zip'
#   - rows in file: 189642
#   - Files: 158823
#   - Valors nuls:
# PROVINCIA      1492
# ELÉCTRICO    150269
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Diesel      HEV             48
#             PHEV             2
#             [N/D]        70678
# Eléctrico   BEV            519
#             HEV             23
#             PHEV           309
#             REEV            27
#             [N/D]            6
# GLP         [N/D]         2304
# GNC         [N/D]          746
# GNL         [N/D]            1
# Gasolina    HEV           7454
#             PHEV           171
#             [N/D]        76331
# Otros       HEV              1
# [N/A]       [N/D]          203
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión      203
#             Diesel          Combustión    70678
#                             HEV              48
#             GLP             GLP            2304
#             GNC             GNC             746
#             GNL             GNL               1
#             Gasolina        Combustión    76331
#                             HEV            7477
#             Otros           HEV               1
# Eléctrico   Diesel          PHEV              2
#             Eléctrico       BEV             525
#             Gasolina        PHEV            480
#                             REEV             27
# Name: MOTOR, dtype: int64
#   - Total rows: 2417
#   - Total vehicles: 158823
# - Reading file: 'txt/export_mensual_mat_201808.zip'
#   - rows in file: 153446
#   - Files: 130947
#   - Valors nuls:
# PROVINCIA      1525
# MODELO            9
# ELÉCTRICO    123942
# RENTING           2
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Biometano   [N/D]            1
# Diesel      HEV             81
#             [N/D]        59794
# Eléctrico   BEV            396
#             HEV             31
#             PHEV           288
#             REEV            39
#             [N/D]           15
# GLP         [N/D]         2198
# GNC         [N/D]          448
# GNL         [N/D]            1
# Gasolina    HEV           6035
#             PHEV           134
#             [N/D]        61260
# Otros       HEV              1
# [N/A]       [N/D]          225
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión      226
#             Diesel          Combustión    59794
#                             HEV              81
#             GLP             GLP            2198
#             GNC             GNC             448
#             GNL             GNL               1
#             Gasolina        Combustión    61260
#                             HEV            6066
#             Otros           HEV               1
# Eléctrico   Eléctrico       BEV             411
#             Gasolina        PHEV            422
#                             REEV             39
# Name: MOTOR, dtype: int64
#   - Total rows: 2328
#   - Total vehicles: 130947
# - Reading file: 'txt/export_mensual_mat_201809.zip'
#   - rows in file: 116305
#   - Files: 90212
#   - Valors nuls:
# PROVINCIA     1079
# ELÉCTRICO    83659
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Biometano   [N/D]            2
# Diesel      HEV            212
#             PHEV             4
#             [N/D]        43475
# Eléctrico   BEV            650
#             HEV             68
#             PHEV           282
#             REEV            31
#             [N/D]            4
# GLP         [N/D]         1082
# GNC         [N/D]          205
# GNL         [N/D]            5
# Gasolina    HEV           5204
#             PHEV            98
#             [N/D]        38632
# Hidrógeno   FCEV             1
# Otros       HEV              3
# [N/A]       [N/D]          254
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión      257
#             Diesel          Combustión    43475
#                             HEV             212
#             GLP             GLP            1082
#             GNC             GNC             205
#             GNL             GNL               5
#             Gasolina        Combustión    38632
#                             HEV            5272
#             Otros           HEV               3
# Eléctrico   Diesel          PHEV              4
#             Eléctrico       BEV             654
#             Gasolina        PHEV            380
#                             REEV             31
# Name: MOTOR, dtype: int64
#   - Total rows: 2346
#   - Total vehicles: 90212
# - Reading file: 'txt/export_mensual_mat_201810.zip'
#   - rows in file: 144964
#   - Files: 114899
#   - Valors nuls:
# PROVINCIA      1455
# ELÉCTRICO    106773
# RENTING           1
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Butano      [N/D]           10
# Diesel      HEV            221
#             PHEV             3
#             [N/D]        51503
# Eléctrico   BEV            794
#             HEV            141
#             PHEV           320
#             REEV            50
#             [N/D]            3
# GLP         [N/D]         2226
# GNC         [N/D]          294
# GNL         [N/D]            4
# Gasolina    HEV           6475
#             PHEV           121
#             [N/D]        52490
# Otros       HEV              1
#             [N/D]            1
# [N/A]       [N/D]          242
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión      252
#             Diesel          Combustión    51503
#                             HEV             221
#             GLP             GLP            2226
#             GNC             GNC             294
#             GNL             GNL               4
#             Gasolina        Combustión    52490
#                             HEV            6616
#             Otros           Combustión        1
#                             HEV               1
# Eléctrico   Diesel          PHEV              3
#             Eléctrico       BEV             797
#             Gasolina        PHEV            441
#                             REEV             50
# Name: MOTOR, dtype: int64
#   - Total rows: 2470
#   - Total vehicles: 114899
# - Reading file: 'txt/export_mensual_mat_201811.zip'
#   - rows in file: 141699
#   - Files: 116989
#   - Valors nuls:
# PROVINCIA      1321
# ELÉCTRICO    109226
# RENTING           3
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Diesel      HEV            164
#             PHEV             5
#             [N/D]        49453
# Eléctrico   BEV            889
#             HEV            117
#             PHEV           305
#             REEV            37
#             [N/D]            4
# GLP         HEV              4
#             [N/D]         2312
# GNC         [N/D]          199
# Gasolina    HEV           6040
#             PHEV           202
#             [N/D]        57020
# Hidrógeno   [N/D]            7
# [N/A]       [N/D]          231
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión      231
#             Diesel          Combustión    49453
#                             HEV             164
#             GLP             GLP            2312
#                             HEV               4
#             GNC             GNC             199
#             Gasolina        Combustión    57020
#                             HEV            6157
# Eléctrico   Diesel          PHEV              5
#             Eléctrico       BEV             893
#             Gasolina        PHEV            507
#                             REEV             37
#             Hidrógeno       Hidrógeno         7
# Name: MOTOR, dtype: int64
#   - Total rows: 2433
#   - Total vehicles: 116989
# - Reading file: 'txt/export_mensual_mat_201812.zip'
#   - rows in file: 148088
#   - Files: 123989
#   - Valors nuls:
# PROVINCIA      1381
# ELÉCTRICO    115306
# RENTING           1
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Diesel      HEV            335
#             PHEV             3
#             [N/D]        52766
# Eléctrico   BEV           1724
#             HEV            186
#             PHEV           613
#             REEV            27
#             [N/D]            7
# GLP         [N/D]         2007
# GNC         [N/D]          210
# Gasolina    HEV           5548
#             PHEV           246
#             [N/D]        60117
# Otros       HEV              1
# [N/A]       [N/D]          199
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión      199
#             Diesel          Combustión    52766
#                             HEV             335
#             GLP             GLP            2007
#             GNC             GNC             210
#             Gasolina        Combustión    60117
#                             HEV            5734
#             Otros           HEV               1
# Eléctrico   Diesel          PHEV              3
#             Eléctrico       BEV            1731
#             Gasolina        PHEV            859
#                             REEV             27
# Name: MOTOR, dtype: int64
#   - Total rows: 2419
#   - Total vehicles: 123989
# - Reading file: 'txt/export_mensual_mat_201901.zip'
#   - rows in file: 144411
#   - Files: 118840
#   - Valors nuls:
# PROVINCIA      1510
# ELÉCTRICO    109752
# RENTING           4
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Butano      [N/D]            5
# Diesel      HEV            744
#             PHEV             1
#             [N/D]        47905
# Eléctrico   BEV            821
#             HEV            183
#             PHEV           322
#             REEV            30
#             [N/D]           51
# GLP         [N/D]         2149
# GNC         HEV              1
#             [N/D]          229
# GNL         [N/D]           18
# Gasolina    BEV              1
#             HEV           6764
#             PHEV           221
#             [N/D]        59215
# [N/A]       [N/D]          180
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión      186
#             Diesel          Combustión    47905
#                             HEV             744
#             GLP             GLP            2149
#             GNC             GNC             229
#                             HEV               1
#             GNL             GNL              18
#             Gasolina        Combustión    59215
#                             HEV            6947
# Eléctrico   Diesel          PHEV              1
#             Eléctrico       BEV             872
#             Gasolina        PHEV            543
#                             REEV             30
# Name: MOTOR, dtype: int64
#   - Total rows: 2563
#   - Total vehicles: 118840
# - Reading file: 'txt/export_mensual_mat_201902.zip'
#   - rows in file: 148556
#   - Files: 125760
#   - Valors nuls:
# PROVINCIA      1448
# MODELO            1
# ELÉCTRICO    117100
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Butano      HEV              1
#             [N/D]           16
# Diesel      HEV            500
#             PHEV             5
#             [N/D]        50897
# Eléctrico   BEV           1044
#             HEV            121
#             PHEV           275
#             REEV            36
#             [N/D]            2
# GLP         HEV              2
#             [N/D]         2079
# GNC         [N/D]          304
# GNL         [N/D]            9
# Gasolina    BEV              3
#             HEV           6462
#             PHEV           210
#             [N/D]        63580
# Hidrógeno   [N/D]            1
# Otros       HEV              1
# [N/A]       [N/D]          212
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión      232
#             Diesel          Combustión    50897
#                             HEV             500
#             GLP             GLP            2079
#                             HEV               2
#             GNC             GNC             304
#             GNL             GNL               9
#             Gasolina        Combustión    63580
#                             HEV            6583
#             Otros           HEV               1
# Eléctrico   Diesel          PHEV              5
#             Eléctrico       BEV            1046
#             Gasolina        PHEV            485
#                             REEV             36
#             Hidrógeno       Hidrógeno         1
# Name: MOTOR, dtype: int64
#   - Total rows: 2456
#   - Total vehicles: 125760
# - Reading file: 'txt/export_mensual_mat_201903.zip'
#   - rows in file: 178763
#   - Files: 151592
#   - Valors nuls:
# PROVINCIA      1288
# ELÉCTRICO    141232
# RENTING           1
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Butano      [N/D]            6
# Diesel      HEV            390
#             PHEV             9
#             [N/D]        56610
# Eléctrico   BEV           1513
#             HEV            140
#             PHEV           245
#             REEV            27
#             [N/D]            5
# GLP         [N/D]         2459
# GNC         [N/D]          390
# GNL         [N/D]            1
# Gasolina    HEV           7453
#             PHEV           583
#             [N/D]        81573
# [N/A]       [N/D]          188
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión      194
#             Diesel          Combustión    56610
#                             HEV             390
#             GLP             GLP            2459
#             GNC             GNC             390
#             GNL             GNL               1
#             Gasolina        Combustión    81573
#                             HEV            7593
# Eléctrico   Diesel          PHEV              9
#             Eléctrico       BEV            1518
#             Gasolina        PHEV            828
#                             REEV             27
# Name: MOTOR, dtype: int64
#   - Total rows: 2597
#   - Total vehicles: 151592
# - Reading file: 'txt/export_mensual_mat_201904.zip'
#   - rows in file: 174680
#   - Files: 147832
#   - Valors nuls:
# PROVINCIA      1166
# ELÉCTRICO    138340
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Butano      [N/D]            5
# Diesel      HEV            587
#             PHEV             5
#             [N/D]        56035
# Eléctrico   BEV            811
#             HEV            152
#             PHEV           207
#             REEV            26
#             [N/D]           10
# GLP         [N/D]         2499
# GNC         [N/D]          591
# GNL         [N/D]            9
# Gasolina    HEV           7210
#             PHEV           493
#             [N/D]        78974
# Otros       HEV              1
# [N/A]       [N/D]          217
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión      222
#             Diesel          Combustión    56035
#                             HEV             587
#             GLP             GLP            2499
#             GNC             GNC             591
#             GNL             GNL               9
#             Gasolina        Combustión    78974
#                             HEV            7362
#             Otros           HEV               1
# Eléctrico   Diesel          PHEV              5
#             Eléctrico       BEV             821
#             Gasolina        PHEV            700
#                             REEV             26
# Name: MOTOR, dtype: int64
#   - Total rows: 2652
#   - Total vehicles: 147832
# - Reading file: 'txt/export_mensual_mat_201905.zip'
#   - rows in file: 188120
#   - Files: 155978
#   - Valors nuls:
# PROVINCIA      1373
# MODELO            1
# ELÉCTRICO    143393
# RENTING           1
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Biometano   [N/D]            1
# Butano      [N/D]            3
# Diesel      HEV           1133
#             PHEV             9
#             [N/D]        60476
# Eléctrico   BEV           1195
#             HEV            127
#             PHEV           206
#             REEV            30
#             [N/D]            9
# GLP         [N/D]         2549
# GNC         HEV             18
#             [N/D]         1031
# GNL         [N/D]            6
# Gasolina    HEV           9371
#             PHEV           495
#             [N/D]        79066
# Otros       HEV              1
#             [N/D]            1
# [N/A]       [N/D]          251
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión      255
#             Diesel          Combustión    60476
#                             HEV            1133
#             GLP             GLP            2549
#             GNC             GNC            1031
#                             HEV              18
#             GNL             GNL               6
#             Gasolina        Combustión    79066
#                             HEV            9498
#             Otros           Combustión        1
#                             HEV               1
# Eléctrico   Diesel          PHEV              9
#             Eléctrico       BEV            1204
#             Gasolina        PHEV            701
#                             REEV             30
# Name: MOTOR, dtype: int64
#   - Total rows: 2764
#   - Total vehicles: 155978
# - Reading file: 'txt/export_mensual_mat_201906.zip'
#   - rows in file: 191594
#   - Files: 159145
#   - Valors nuls:
# PROVINCIA      1391
# MODELO            1
# ELÉCTRICO    147646
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Butano      [N/D]            5
# Diesel      HEV           1214
#             PHEV            15
#             [N/D]        57573
# Eléctrico   BEV           1403
#             HEV            179
#             PHEV           111
#             REEV            19
#             [N/D]            8
# GLP         HEV              1
#             PHEV             1
#             [N/D]         2670
# GNC         [N/D]          926
# GNL         [N/D]            8
# Gasolina    HEV           8186
#             HVE              1
#             NOVC             2
#             PHEV           361
#             [N/D]        86230
# Hidrógeno   PHEV             5
# Otros       BEV              1
# [N/A]       [N/D]          226
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión      234
#             Diesel          Combustión    57573
#                             HEV            1214
#             GLP             GLP            2670
#                             HEV               1
#             GNC             GNC             926
#             GNL             GNL               8
#             Gasolina        Combustión    86230
#                             HEV            8365
# Eléctrico   Diesel          PHEV             15
#             Eléctrico       BEV            1411
#             GLP             PHEV              1
#             Gasolina        PHEV            472
#                             REEV             19
#             Hidrógeno       PHEV              5
#             Otros           BEV               1
# Name: MOTOR, dtype: int64
#   - Total rows: 2716
#   - Total vehicles: 159145
# - Reading file: 'txt/export_mensual_mat_201907.zip'
#   - rows in file: 180120
#   - Files: 145422
#   - Valors nuls:
# PROVINCIA      1272
# ELÉCTRICO    133802
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Biometano   [N/D]            1
# Butano      [N/D]            1
# Diesel      HEV           1753
#             PHEV            15
#             [N/D]        54040
# Eléctrico   BEV            917
#             HEV             80
#             PHEV           115
#             REEV            29
#             [N/D]           10
# GLP         [N/D]         2752
# GNC         [N/D]          931
# GNL         [N/D]            4
# Gasolina    HEV           8302
#             PHEV           393
#             REEV             1
#             [N/D]        75798
# Hidrógeno   PHEV            14
# Otros       HEV              1
#             [N/D]           10
# [N/A]       [N/D]          255
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión      257
#             Diesel          Combustión    54040
#                             HEV            1753
#             GLP             GLP            2752
#             GNC             GNC             931
#             GNL             GNL               4
#             Gasolina        Combustión    75798
#                             HEV            8382
#             Otros           Combustión       10
#                             HEV               1
# Eléctrico   Diesel          PHEV             15
#             Eléctrico       BEV             927
#             Gasolina        PHEV            508
#                             REEV             30
#             Hidrógeno       PHEV             14
# Name: MOTOR, dtype: int64
#   - Total rows: 2712
#   - Total vehicles: 145422
# - Reading file: 'txt/export_mensual_mat_201908.zip'
#   - rows in file: 118439
#   - Files: 97192
#   - Valors nuls:
# PROVINCIA     1196
# ELÉCTRICO    89020
# RENTING          2
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Butano      HEV              4
#             [N/D]            1
# Diesel      HEV           1015
#             PHEV             6
#             [N/D]        38857
# Eléctrico   BEV            650
#             HEV             61
#             PHEV            89
#             REEV            15
#             [N/D]            2
# GLP         [N/D]         2433
# GNC         [N/D]          566
# GNL         [N/D]            7
# Gasolina    HEV           5953
#             PHEV           361
#             [N/D]        46955
# Hidrógeno   PHEV            18
# [N/A]       [N/D]          199
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión      204
#             Diesel          Combustión    38857
#                             HEV            1015
#             GLP             GLP            2433
#             GNC             GNC             566
#             GNL             GNL               7
#             Gasolina        Combustión    46955
#                             HEV            6014
# Eléctrico   Diesel          PHEV              6
#             Eléctrico       BEV             652
#             Gasolina        PHEV            450
#                             REEV             15
#             Hidrógeno       PHEV             18
# Name: MOTOR, dtype: int64
#   - Total rows: 2468
#   - Total vehicles: 97192
# - Reading file: 'txt/export_mensual_mat_201909.zip'
#   - rows in file: 129774
#   - Files: 102934
#   - Valors nuls:
# PROVINCIA     1166
# MODELO           2
# ELÉCTRICO    92873
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Biometano   [N/D]            1
# Diesel      HEV           1517
#             PHEV            10
#             [N/D]        40226
# Eléctrico   BEV            953
#             HEV             49
#             PHEV            55
#             REEV            20
# GLP         HEV              2
#             [N/D]         2137
# GNC         [N/D]          672
# GNL         [N/D]            1
# Gasolina    HEV           6947
#             PHEV           502
#             [N/D]        49620
# Hidrógeno   PHEV             5
# Otros       HEV              1
# [N/A]       [N/D]          216
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión      217
#             Diesel          Combustión    40226
#                             HEV            1517
#             GLP             GLP            2137
#                             HEV               2
#             GNC             GNC             672
#             GNL             GNL               1
#             Gasolina        Combustión    49620
#                             HEV            6996
#             Otros           HEV               1
# Eléctrico   Diesel          PHEV             10
#             Eléctrico       BEV             953
#             Gasolina        PHEV            557
#                             REEV             20
#             Hidrógeno       PHEV              5
# Name: MOTOR, dtype: int64
#   - Total rows: 2578
#   - Total vehicles: 102934
# - Reading file: 'txt/export_mensual_mat_201910.zip'
#   - rows in file: 153445
#   - Files: 121812
#   - Valors nuls:
# PROVINCIA      1445
# ELÉCTRICO    109495
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Butano      [N/D]           13
# Diesel      HEV           2118
#             PHEV            12
#             [N/D]        50161
# Eléctrico   BEV           1083
#             HEV             40
#             PHEV            43
#             REEV            28
#             [N/D]            1
# GLP         HEV              5
#             [N/D]         1388
# GNC         [N/D]         1030
# GNL         [N/D]            1
# Gasolina    HEV           8212
#             PHEV           766
#             [N/D]        56809
# Hidrógeno   PHEV             6
# Otros       HEV              4
# [N/A]       [N/D]           92
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión      105
#             Diesel          Combustión    50161
#                             HEV            2118
#             GLP             GLP            1388
#                             HEV               5
#             GNC             GNC            1030
#             GNL             GNL               1
#             Gasolina        Combustión    56809
#                             HEV            8252
#             Otros           HEV               4
# Eléctrico   Diesel          PHEV             12
#             Eléctrico       BEV            1084
#             Gasolina        PHEV            809
#                             REEV             28
#             Hidrógeno       PHEV              6
# Name: MOTOR, dtype: int64
#   - Total rows: 2772
#   - Total vehicles: 121812
# - Reading file: 'txt/export_mensual_mat_201911.zip'
#   - rows in file: 144687
#   - Files: 119240
#   - Valors nuls:
# PROVINCIA      1330
# ELÉCTRICO    105506
# RENTING           3
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Butano      [N/D]            5
# Diesel      HEV           2192
#             PHEV            24
#             [N/D]        48159
# Eléctrico   BEV            981
#             HEV             44
#             PHEV            33
#             REEV            16
#             [N/D]            1
# GLP         HEV              1
#             [N/D]          937
# GNC         [N/D]          827
# GNL         [N/D]            9
# Gasolina    HEV           9618
#             PHEV           819
#             [N/D]        55568
# Hidrógeno   FCEV             1
#             PHEV             5
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión        6
#             Diesel          Combustión    48159
#                             HEV            2192
#             GLP             GLP             937
#                             HEV               1
#             GNC             GNC             827
#             GNL             GNL               9
#             Gasolina        Combustión    55568
#                             HEV            9662
# Eléctrico   Diesel          PHEV             24
#             Eléctrico       BEV             982
#             Gasolina        PHEV            852
#                             REEV             16
#             Hidrógeno       PHEV              5
# Name: MOTOR, dtype: int64
#   - Total rows: 2556
#   - Total vehicles: 119240
# - Reading file: 'txt/export_mensual_mat_201912.zip'
#   - rows in file: 151341
#   - Files: 130173
#   - Valors nuls:
# PROVINCIA      1390
# ELÉCTRICO    116775
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Biometano   [N/D]            1
# Butano      [N/D]           10
# Diesel      HEV           2532
#             PHEV            18
#             [N/D]        51076
# Eléctrico   BEV           1124
#             HEV             61
#             PHEV            31
#             REEV             8
#             [N/D]            3
# GLP         PHEV             1
#             [N/D]          823
# GNC         [N/D]          604
# GNL         [N/D]            5
# Gasolina    HEV           8821
#             PHEV           797
#             [N/D]        64248
# Hidrógeno   PHEV             5
# Otros       [N/D]            1
# [N/A]       [N/D]            4
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión       15
#             Diesel          Combustión    51076
#                             HEV            2532
#             GLP             GLP             823
#             GNC             GNC             604
#             GNL             GNL               5
#             Gasolina        Combustión    64248
#                             HEV            8882
#             Otros           Combustión        1
# Eléctrico   Diesel          PHEV             18
#             Eléctrico       BEV            1127
#             GLP             PHEV              1
#             Gasolina        PHEV            828
#                             REEV              8
#             Hidrógeno       PHEV              5
# Name: MOTOR, dtype: int64
#   - Total rows: 2539
#   - Total vehicles: 130173
# - Reading file: 'txt/export_mensual_mat_202001.zip'
#   - rows in file: 133560
#   - Files: 109178
#   - Valors nuls:
# PROVINCIA     1079
# ELÉCTRICO    93828
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Butano      HEV              1
#             [N/D]            2
# Diesel      HEV           1990
#             PHEV            14
#             [N/D]        43237
# Eléctrico   BEV           1863
#             HEV             33
#             PHEV            26
#             REEV            18
# GLP         [N/D]          595
# GNC         [N/D]          820
# GNL         [N/D]            1
# Gasolina    HEV           9931
#             PHEV          1462
#             REEV             2
#             [N/D]        49173
# Hidrógeno   PHEV             8
# Otros       HEV              2
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión        3
#             Diesel          Combustión    43237
#                             HEV            1990
#             GLP             GLP             595
#             GNC             GNC             820
#             GNL             GNL               1
#             Gasolina        Combustión    49173
#                             HEV            9964
#             Otros           HEV               2
# Eléctrico   Diesel          PHEV             14
#             Eléctrico       BEV            1863
#             Gasolina        PHEV           1488
#                             REEV             20
#             Hidrógeno       PHEV              8
# Name: MOTOR, dtype: int64
#   - Total rows: 2603
#   - Total vehicles: 109178
# - Reading file: 'txt/export_mensual_mat_202002.zip'
#   - rows in file: 144158
#   - Files: 119366
#   - Valors nuls:
# PROVINCIA      1228
# ELÉCTRICO    103992
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Butano      [N/D]            3
# Diesel      HEV           2528
#             PHEV            26
#             [N/D]        47565
# Eléctrico   BEV           1774
#             HEV             24
#             PHEV            27
#             REEV            24
#             [N/D]            1
# GLP         HEV              2
#             [N/D]          421
# GNC         [N/D]          712
# GNL         [N/D]            2
# Gasolina    HEV           9733
#             PHEV          1229
#             REEV             5
#             [N/D]        55286
# Hidrógeno   FCEV             1
#             PHEV             1
# Otros       [N/D]            1
# [N/A]       [N/D]            1
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión        5
#             Diesel          Combustión    47565
#                             HEV            2528
#             GLP             GLP             421
#                             HEV               2
#             GNC             GNC             712
#             GNL             GNL               2
#             Gasolina        Combustión    55286
#                             HEV            9757
#             Otros           Combustión        1
# Eléctrico   Diesel          PHEV             26
#             Eléctrico       BEV            1775
#             Gasolina        PHEV           1256
#                             REEV             29
#             Hidrógeno       PHEV              1
# Name: MOTOR, dtype: int64
#   - Total rows: 2613
#   - Total vehicles: 119366
# - Reading file: 'txt/export_mensual_mat_202003.zip'
#   - rows in file: 64218
#   - Files: 48898
#   - Valors nuls:
# PROVINCIA      468
# ELÉCTRICO    41450
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Butano      [N/D]            5
# Diesel      HEV            939
#             PHEV             6
#             [N/D]        18755
# Eléctrico   BEV            849
#             HEV             18
#             PHEV            23
#             REEV             7
#             [N/D]            3
# GLP         [N/D]          190
# GNC         [N/D]          363
# GNL         [N/D]            6
# Gasolina    HEV           4964
#             PHEV           639
#             REEV             3
#             [N/D]        22125
# Hidrógeno   [N/D]            1
# [N/A]       [N/D]            2
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión        7
#             Diesel          Combustión    18755
#                             HEV             939
#             GLP             GLP             190
#             GNC             GNC             363
#             GNL             GNL               6
#             Gasolina        Combustión    22125
#                             HEV            4982
# Eléctrico   Diesel          PHEV              6
#             Eléctrico       BEV             852
#             Gasolina        PHEV            662
#                             REEV             10
#             Hidrógeno       Hidrógeno         1
# Name: MOTOR, dtype: int64
#   - Total rows: 2020
#   - Total vehicles: 48898
# - Reading file: 'txt/export_mensual_mat_202004.zip'
#   - rows in file: 10682
#   - Files: 6854
#   - Valors nuls:
# PROVINCIA      41
# ELÉCTRICO    6334
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Diesel      HEV            89
#             PHEV            1
#             [N/D]        3557
# Eléctrico   BEV           101
#             HEV             9
#             PHEV            5
# GLP         [N/D]          12
# GNC         [N/D]         147
# GNL         [N/D]           3
# Gasolina    HEV           250
#             PHEV           63
#             REEV            2
#             [N/D]        2614
# [N/A]       [N/D]           1
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión       1
#             Diesel          Combustión    3557
#                             HEV             89
#             GLP             GLP             12
#             GNC             GNC            147
#             GNL             GNL              3
#             Gasolina        Combustión    2614
#                             HEV            259
# Eléctrico   Diesel          PHEV             1
#             Eléctrico       BEV            101
#             Gasolina        PHEV            68
#                             REEV             2
# Name: MOTOR, dtype: int64
#   - Total rows: 853
#   - Total vehicles: 6854
# - Reading file: 'txt/export_mensual_mat_202005.zip'
#   - rows in file: 61532
#   - Files: 45287
#   - Valors nuls:
# PROVINCIA      591
# ELÉCTRICO    39324
# RENTING          4
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Butano      [N/D]            4
# Diesel      HEV            953
#             PHEV             7
#             [N/D]        20580
# Eléctrico   BEV            435
#             HEV             10
#             PHEV             5
#             REEV             8
# GLP         [N/D]          328
# GNC         [N/D]          256
# GNL         [N/D]            5
# Gasolina    HEV           3796
#             PHEV           747
#             REEV             1
#             [N/D]        18151
# Otros       HEV              1
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión        4
#             Diesel          Combustión    20580
#                             HEV             953
#             GLP             GLP             328
#             GNC             GNC             256
#             GNL             GNL               5
#             Gasolina        Combustión    18151
#                             HEV            3806
#             Otros           HEV               1
# Eléctrico   Diesel          PHEV              7
#             Eléctrico       BEV             435
#             Gasolina        PHEV            752
#                             REEV              9
# Name: MOTOR, dtype: int64
#   - Total rows: 1939
#   - Total vehicles: 45287
# - Reading file: 'txt/export_mensual_mat_202006.zip'
#   - rows in file: 140071
#   - Files: 106410
#   - Valors nuls:
# PROVINCIA     1107
# ELÉCTRICO    91945
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Butano      [N/D]            4
# Diesel      HEV           2169
#             PHEV            22
#             [N/D]        44802
# Eléctrico   BEV            925
#             HEV             11
#             PHEV            24
#             REEV            12
#             [N/D]            1
# GLP         HEV              1
#             [N/D]          804
# GNC         [N/D]          476
# GNL         [N/D]            1
# Gasolina    HEV           9829
#             PHEV          1464
#             REEV             8
#             [N/D]        45854
# Otros       [N/D]            1
# [N/A]       [N/D]            2
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión        6
#             Diesel          Combustión    44802
#                             HEV            2169
#             GLP             GLP             804
#                             HEV               1
#             GNC             GNC             476
#             GNL             GNL               1
#             Gasolina        Combustión    45854
#                             HEV            9840
#             Otros           Combustión        1
# Eléctrico   Diesel          PHEV             22
#             Eléctrico       BEV             926
#             Gasolina        PHEV           1488
#                             REEV             20
# Name: MOTOR, dtype: int64
#   - Total rows: 2519
#   - Total vehicles: 106410
# - Reading file: 'txt/export_mensual_mat_202007.zip'
#   - rows in file: 186781
#   - Files: 147103
#   - Valors nuls:
# PROVINCIA      1429
# ELÉCTRICO    124379
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Butano      [N/D]            4
# Diesel      HEV           3472
#             PHEV            36
#             [N/D]        56281
# Eléctrico   BEV           1673
#             HEV             36
#             PHEV            25
#             REEV            18
#             [N/D]            1
# GLP         HEV              2
#             [N/D]         1679
# GNC         [N/D]          636
# GNL         [N/D]            3
# Gasolina    HEV          15079
#             PHEV          2378
#             REEV             4
#             [N/D]        65771
# Hidrógeno   PHEV             1
# [N/A]       [N/D]            4
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión        8
#             Diesel          Combustión    56281
#                             HEV            3472
#             GLP             GLP            1679
#                             HEV               2
#             GNC             GNC             636
#             GNL             GNL               3
# ...
# Name: MOTOR, dtype: int64
#   - Total rows: 2992
#   - Total vehicles: 81923
# - Reading file: 'txt/export_mensual_mat_202203.zip'
#   - rows in file: 109184
#   - Files: 81642
#   - Valors nuls:
# PROVINCIA      769
# MODELO          27
# ELÉCTRICO    57614
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Biometano   [N/D]            3
# Diesel      HEV           2509
#             PHEV           258
#             [N/D]        28035
# Eléctrico   BEV           3469
#             HEV             31
#             PHEV            26
#             REEV            15
#             [N/D]           16
# GLP         HEV              8
#             [N/D]         1011
# GNC         HEV             10
#             [N/D]          154
# GNL         HEV              1
#             [N/D]            2
# Gasolina    HEV          14525
#             PHEV          3168
#             [N/D]        28390
# Hidrógeno   FCEV             7
# Otros       HEV              1
# [N/A]       [N/D]            3
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión       13
#             Diesel          Combustión    28035
#                             HEV            2509
#             GLP             GLP            1011
#                             HEV               8
#             GNC             GNC             154
#                             HEV              10
#             GNL             GNL               2
#                             HEV               1
#             Gasolina        Combustión    28390
#                             HEV           14556
#             Otros           HEV               1
# Eléctrico   Diesel          PHEV            258
#             Eléctrico       BEV            3485
#             Gasolina        PHEV           3194
#                             REEV             15
# Name: MOTOR, dtype: int64
#   - Total rows: 2811
#   - Total vehicles: 81642
# - Reading file: 'txt/export_mensual_mat_202204.zip'
#   - rows in file: 113859
#   - Files: 89059
#   - Valors nuls:
# PROVINCIA      699
# MODELO          23
# ELÉCTRICO    63258
# RENTING          3
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Diesel      HEV           3137
#             PHEV           187
#             [N/D]        27716
# Eléctrico   BEV           2141
#             HEV             32
#             PHEV            14
#             REEV             5
#             [N/D]           71
# GLP         [N/D]         1352
# GNC         HEV             42
#             [N/D]          168
# GNL         [N/D]            2
# Gasolina    HEV          16150
#             PHEV          4087
#             REEV             6
#             [N/D]        33947
# Otros       [N/D]            1
# [N/A]       [N/D]            1
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión        1
#             Diesel          Combustión    27716
#                             HEV            3137
#             GLP             GLP            1352
#             GNC             GNC             168
#                             HEV              42
#             GNL             GNL               2
#             Gasolina        Combustión    33947
#                             HEV           16182
#             Otros           Combustión        1
# Eléctrico   Diesel          PHEV            187
#             Eléctrico       BEV            2212
#             Gasolina        PHEV           4101
#                             REEV             11
# Name: MOTOR, dtype: int64
#   - Total rows: 3051
#   - Total vehicles: 89059
# - Reading file: 'txt/export_mensual_mat_202205.zip'
#   - rows in file: 139537
#   - Files: 107895
#   - Valors nuls:
# PROVINCIA      862
# MODELO          30
# ELÉCTRICO    75008
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Biometano   [N/D]            1
# Diesel      HEV           3461
#             PHEV           226
#             [N/D]        31834
# Eléctrico   BEV           2412
#             HEV             21
#             PHEV            22
#             REEV            17
#             [N/D]            6
# GLP         HEV              4
#             [N/D]         1164
# GNC         HEV             19
#             [N/D]          145
# GNL         [N/D]            2
# Gasolina    HEV          22028
#             PHEV          4673
#             REEV             4
#             [N/D]        41855
# [N/A]       [N/D]            1
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión        2
#             Diesel          Combustión    31834
#                             HEV            3461
#             GLP             GLP            1164
#                             HEV               4
#             GNC             GNC             145
#                             HEV              19
#             GNL             GNL               2
#             Gasolina        Combustión    41855
#                             HEV           22049
# Eléctrico   Diesel          PHEV            226
#             Eléctrico       BEV            2418
#             Gasolina        PHEV           4695
#                             REEV             21
# Name: MOTOR, dtype: int64
#   - Total rows: 2889
#   - Total vehicles: 107895
# - Reading file: 'txt/export_mensual_mat_202206.zip'
#   - rows in file: 143875
#   - Files: 111291
#   - Valors nuls:
# PROVINCIA       889
# MODELO           22
# PROPULSIÓN        5
# ELÉCTRICO     77732
# RENTING          10
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Diesel      HEV           3700
#             PHEV           217
#             [N/D]        32841
# Eléctrico   BEV           3503
#             HEV             19
#             PHEV            25
#             REEV             2
#             [N/D]            3
# GLP         [N/D]         2210
# GNC         [N/D]          180
# GNL         [N/D]            5
# Gasolina    HEV          21954
#             PHEV          4126
#             REEV            13
#             [N/D]        42487
# [N/A]       [N/D]            1
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión        6
#             Diesel          Combustión    32841
#                             HEV            3700
#             GLP             GLP            2210
#             GNC             GNC             180
#             GNL             GNL               5
#             Gasolina        Combustión    42487
#                             HEV           21973
# Eléctrico   Diesel          PHEV            217
#             Eléctrico       BEV            3506
#             Gasolina        PHEV           4151
#                             REEV             15
# Name: MOTOR, dtype: int64
#   - Total rows: 2794
#   - Total vehicles: 111291
# - Reading file: 'txt/export_mensual_mat_202207.zip'
#   - rows in file: 123719
#   - Files: 95560
#   - Valors nuls:
# PROVINCIA       638
# MODELO           17
# PROPULSIÓN        2
# ELÉCTRICO     68532
# RENTING           1
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Biometano   [N/D]            2
# Diesel      HEV           3038
#             PHEV           201
#             [N/D]        29690
# Eléctrico   BEV           2587
#             HEV             50
#             PHEV            21
#             REEV             8
#             [N/D]            3
# GLP         [N/D]         1254
# GNC         [N/D]          106
# GNL         HEV              1
#             [N/D]            3
# Gasolina    HEV          17614
#             PHEV          3498
#             REEV             9
#             [N/D]        37472
# Otros       HEV              1
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión        4
#             Diesel          Combustión    29690
#                             HEV            3038
#             GLP             GLP            1254
#             GNC             GNC             106
#             GNL             GNL               3
#                             HEV               1
#             Gasolina        Combustión    37472
#                             HEV           17664
#             Otros           HEV               1
# Eléctrico   Diesel          PHEV            201
#             Eléctrico       BEV            2590
#             Gasolina        PHEV           3519
#                             REEV             17
# Name: MOTOR, dtype: int64
#   - Total rows: 2725
#   - Total vehicles: 95560
# - Reading file: 'txt/export_mensual_mat_202208.zip'
#   - rows in file: 92219
#   - Files: 71234
#   - Valors nuls:
# PROVINCIA       683
# MODELO           13
# PROPULSIÓN        2
# ELÉCTRICO     50409
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Biometano   HEV              1
#             [N/D]            1
# Diesel      HEV           2366
#             PHEV           156
#             [N/D]        23947
# Eléctrico   BEV           1864
#             HEV             30
#             PHEV            18
#             REEV             6
#             [N/D]            8
# GLP         [N/D]          962
# GNC         [N/D]           85
# GNL         [N/D]            2
# Gasolina    HEV          13716
#             PHEV          2664
#             REEV             4
#             [N/D]        25402
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión        4
#             Diesel          Combustión    23947
#                             HEV            2366
#             GLP             GLP             962
#             GNC             GNC              85
#             GNL             GNL               2
#             Gasolina        Combustión    25402
#                             HEV           13746
# Eléctrico   Diesel          PHEV            156
#             Eléctrico       BEV            1872
#             Gasolina        PHEV           2682
#                             REEV             10
# Name: MOTOR, dtype: int64
#   - Total rows: 2621
#   - Total vehicles: 71234
# - Reading file: 'txt/export_mensual_mat_202209.zip'
#   - rows in file: 114542
#   - Files: 88081
#   - Valors nuls:
# PROVINCIA      759
# MODELO           6
# ELÉCTRICO    58540
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Biodiesel   [N/D]            1
# Diesel      HEV           3145
#             PHEV           146
#             [N/D]        28381
# Eléctrico   BEV           3811
#             HEV             37
#             PHEV            29
#             REEV            19
#             [N/D]           15
# GLP         HEV              2
#             [N/D]         1311
# GNC         [N/D]          125
# GNL         [N/D]            4
# Gasolina    0                1
#             HEV          18255
#             PHEV          4094
#             REEV             2
#             [N/D]        28703
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión        2
#             Diesel          Combustión    28381
#                             HEV            3145
#             GLP             GLP            1311
#                             HEV               2
#             GNC             GNC             125
#             GNL             GNL               4
#             Gasolina        Combustión    28703
#                             HEV           18292
# Eléctrico   Diesel          PHEV            146
#             Eléctrico       BEV            3826
#             Gasolina        PHEV           4123
#                             REEV             21
# Name: MOTOR, dtype: int64
#   - Total rows: 2842
#   - Total vehicles: 88081
# - Reading file: 'txt/export_mensual_mat_202210.zip'
#   - rows in file: 114043
#   - Files: 87227
#   - Valors nuls:
# PROVINCIA      799
# MODELO           6
# ELÉCTRICO    58832
# RENTING          1
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Diesel      HEV           2862
#             PHEV           150
#             [N/D]        28149
# Eléctrico   BEV           3219
#             HEV             31
#             PHEV            23
#             REEV             7
#             [N/D]            9
# GLP         HEV              1
#             PHEV             1
#             [N/D]         1026
# GNC         [N/D]          138
# GNL         [N/D]           10
# Gasolina    HEV          18175
#             PHEV          3911
#             REEV            15
#             [N/D]        29497
# Hidrógeno   [N/D]            2
# Otros       [N/D]            1
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE  TECNOLOGÍA
# Combustión  Diesel       Combustión    28149
#                          HEV            2862
#             GLP          GLP            1026
#                          HEV               1
#             GNC          GNC             138
#             GNL          GNL              10
#             Gasolina     Combustión    29497
#                          HEV           18206
#             Otros        Combustión        1
# Eléctrico   Diesel       PHEV            150
#             Eléctrico    BEV            3228
#             GLP          PHEV              1
#             Gasolina     PHEV           3934
#                          REEV             22
#             Hidrógeno    Hidrógeno         2
# Name: MOTOR, dtype: int64
#   - Total rows: 2881
#   - Total vehicles: 87227
# - Reading file: 'txt/export_mensual_mat_202211.zip'
#   - rows in file: 122290
#   - Files: 95210
#   - Valors nuls:
# PROVINCIA      862
# MODELO          10
# ELÉCTRICO    61008
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Diesel      0                1
#             HEV           3124
#             PHEV           129
#             [N/D]        27791
# Eléctrico   BEV           3957
#             HEV             43
#             PHEV            21
#             REEV             5
#             [N/D]           10
# GLP         [N/D]         1092
# GNC         [N/D]          176
# GNL         [N/D]            7
# Gasolina    HEV          22146
#             PHEV          4769
#             REEV             7
#             [N/D]        31921
# Hidrógeno   [N/D]           10
# Otros       [N/D]            1
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión        1
#             Diesel          Combustión    27791
#                             HEV            3124
#             GLP             GLP            1092
#             GNC             GNC             176
#             GNL             GNL               7
#             Gasolina        Combustión    31921
#                             HEV           22189
#             Otros           Combustión        1
# Eléctrico   Diesel          PHEV            129
#             Eléctrico       BEV            3967
#             Gasolina        PHEV           4790
#                             REEV             12
#             Hidrógeno       Hidrógeno        10
# Name: MOTOR, dtype: int64
#   - Total rows: 2955
#   - Total vehicles: 95210
# - Reading file: 'txt/export_mensual_mat_202212.zip'
#   - rows in file: 119245
#   - Files: 96921
#   - Valors nuls:
# PROVINCIA      842
# MODELO          11
# ELÉCTRICO    65002
# dtype: int64
# PROPULSIÓN  ELÉCTRICO
# Diesel      0                1
#             HEV           3836
#             PHEV           117
#             [N/D]        30010
# Eléctrico   BEV           4171
#             HEV             36
#             PHEV            39
#             REEV             5
#             [N/D]            5
# GLP         HEV              1
#             [N/D]         1882
# GNC         [N/D]          133
# GNL         [N/D]            5
# Gasolina    0                2
#             HEV          19109
#             PHEV          4596
#             REEV             5
#             [N/D]        32967
# Hidrógeno   FCEV             1
# Name: PROPULSIÓN, dtype: int64
# MOTOR       COMBUSTIBLE     TECNOLOGÍA
# Combustión  Combustión G/D  Combustión        4
#             Diesel          Combustión    30010
#                             HEV            3836
#             GLP             GLP            1882
#                             HEV               1
#             GNC             GNC             133
#             GNL             GNL               5
#             Gasolina        Combustión    32967
#                             HEV           19145
# Eléctrico   Diesel          PHEV            117
#             Eléctrico       BEV            4176
#             Gasolina        PHEV           4635
#                             REEV             10
# Name: MOTOR, dtype: int64
#   - Total rows: 2951
#   - Total vehicles: 96921
# TOTAL: 8048312
# TIPO: 6556272
# TRAMITE: 6496293
# N/A: 900
# GROUP: 156782

# %%
# last_day = df["FEC_PROCESO"].max()
# print(
#     last_day, 
#     last_day.strftime('%Y-%m'),
#     last_day_of_month(last_day)
# )

# %%
# fields_resum = ['PERIODO',  'COMBUSTIBLE', 'TECNOLOGÍA', 'REG_EMISIONES', ]
# dades_resum = dades.groupby(fields_resum)[["CO2", "CANTIDAD"]].sum().reset_index()
# dades_resum

# %%
# dades_resum = dades.groupby(fields_resum)[["CO2", "CANTIDAD"]].agg(['count', 'mean', 'sum']).reset_index()
# dades_resum

# %%
df.groupby(field_old)[field_old].count()
df.isna().sum()

if df[field_old].dtypes == int:
    df[field_new] = df[field_old].fillna(99).astype(int).astype(str)
else:
    df[field_new] = df[field_old].fillna("99")
df.isna().sum()

df.groupby(field_new)[field_new].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.groupby(field_old)[field_old].count()
#       2 df.isna().sum()
#       4 if df[field_old].dtypes == int:
#
# File c:\Users\JoseV\.conda\envs\venv\lib\site-packages\pandas\core\frame.py:8399, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8396     raise TypeError("You have to supply one of 'by' and 'level'")
#    8397 axis = self._get_axis_number(axis)
# -> 8399 return DataFrameGroupBy(
#    8400     obj=self,
#    8401     keys=by,
#    8402     axis=axis,
#    8403     level=level,
#    8404     as_index=as_index,
#    8405     sort=sort,
#    8406     group_keys=group_keys,
#    8407     squeeze=squeeze,
#    8408     observed=observed,
#    8409     dropna=dropna,
#    8410 )
#
# File c:\Users\JoseV\.conda\envs\venv\lib\site-packages\pandas\core\groupby\groupby.py:959, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     956 if grouper is None:
#     957     from pandas.core.groupby.grouper import get_grouper
# --> 959     grouper, exclusions, obj = get_grouper(
#     960         obj,
#     961         keys,
#     962         axis=axis,
#     963         level=level,
#     964         sort=sort,
#     965         observed=observed,
#     966         mutated=self.mutated,
#     967         dropna=self.dropna,
#     968     )
#     970 self.obj = obj
#     971 self.axis = obj._get_axis_number(axis)
#
# File c:\Users\JoseV\.conda\envs\venv\lib\site-packages\pandas\core\groupby\grouper.py:888, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     886         in_axis, level, gpr = False, gpr, None
#     887     else:
# --> 888         raise KeyError(gpr)
#     889 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     890     # Add key to exclusions
#     891     exclusions.add(gpr.key)
#
# KeyError: 'CATEGORÍA_VEHÍCULO_ELÉCTRICO'

# %%
if df[field_old].dtypes == int:
    df[field_new] = df[field_old].fillna(99).astype(int).astype(str)
elif df[field_old].dtypes == float:
    df[field_new] = df[field_old].fillna(99).astype(int).astype(str)
else:
    df[field_new] = df[field_old].fillna("99")

df[field_old]
